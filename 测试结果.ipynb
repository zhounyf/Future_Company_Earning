# %%
table['2016']['累计总盈亏'].plot(title = '2016年开仓然后持有至到期天之后的资金曲线',grid = True)

# %%
overlap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3dc1d5d1e85f4f41a6c3797e92e971a4" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3dc1d5d1e85f4f41a6c3797e92e971a4 = echarts.init(document.getElementById('3dc1d5d1e85f4f41a6c3797e92e971a4'), 'light', {renderer: 'canvas'});
# function kline_tooltip_formatter(params) {
#     var text;
#     text = ((((((((((((params[0].seriesName + "<br/>") + "- open:") + params[0].data[1]) + "<br/>") + "- close:") + params[0].data[2]) + "<br/>") + "- lowest:") + params[0].data[3]) + "<br/>") + "- highest:") + params[0].data[4]);
#     return text;
# }
#
# var option_3dc1d5d1e85f4f41a6c3797e92e971a4 = {
#     "title": [
#         {
#             "text": "RB\u6307\u6570",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
# ...

# %%
table['2017']['累计总盈亏'].plot(title = '2017年开仓然后持有至到期天之后的资金曲线',grid = True)

# %%
overlap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5c7fcaf185bc45629aa31382cd2c5110" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5c7fcaf185bc45629aa31382cd2c5110 = echarts.init(document.getElementById('5c7fcaf185bc45629aa31382cd2c5110'), 'light', {renderer: 'canvas'});
# function kline_tooltip_formatter(params) {
#     var text;
#     text = ((((((((((((params[0].seriesName + "<br/>") + "- open:") + params[0].data[1]) + "<br/>") + "- close:") + params[0].data[2]) + "<br/>") + "- lowest:") + params[0].data[3]) + "<br/>") + "- highest:") + params[0].data[4]);
#     return text;
# }
#
# var option_5c7fcaf185bc45629aa31382cd2c5110 = {
#     "title": [
#         {
#             "text": "RB\u6307\u6570",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
# ...

# %%
table['2018']['累计总盈亏'].plot(title = '2018年开仓然后持有至到期天之后的资金曲线',grid = True)

# %%
overlap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="02251bfafaa24ce59108912ff2ee0c08" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_02251bfafaa24ce59108912ff2ee0c08 = echarts.init(document.getElementById('02251bfafaa24ce59108912ff2ee0c08'), 'light', {renderer: 'canvas'});
# function kline_tooltip_formatter(params) {
#     var text;
#     text = ((((((((((((params[0].seriesName + "<br/>") + "- open:") + params[0].data[1]) + "<br/>") + "- close:") + params[0].data[2]) + "<br/>") + "- lowest:") + params[0].data[3]) + "<br/>") + "- highest:") + params[0].data[4]);
#     return text;
# }
#
# var option_02251bfafaa24ce59108912ff2ee0c08 = {
#     "title": [
#         {
#             "text": "RB\u6307\u6570",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
# ...
